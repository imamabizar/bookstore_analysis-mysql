# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mysql.connector as connection

# %%
mydb = connection.connect(host="localhost", database = 'book_data',user="jihan", passwd="rahasia",use_pure=True)
query = "Select * from book_info;"
result_dataFrame = pd.read_sql(query,mydb)
# mydb.close() #close the connection
# Out:
# /var/folders/xn/78g1k9617cn1qznd7dzcqr680000gn/T/ipykernel_8360/4148399654.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_dataFrame = pd.read_sql(query,mydb)

# %%
result_dataFrame = pd.read_sql(query, mydb)
result_dataFrame
# Out:
# /var/folders/xn/78g1k9617cn1qznd7dzcqr680000gn/T/ipykernel_8360/1208603029.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result_dataFrame = pd.read_sql(query, mydb)
#     book_id                                          book_name  \
# 0         1                                       atomic_habit
# 1         2                          the_subtle_art_of not_gaf
# 2         3      the_thing_you_can_see_only_when_you_slow_down
# 3         4                            the_psychology_of_money
# 4         5                                            sapiens
# 5         6                                     norwegian_wood
# 6         7  The Visual MBA : A Quick Guide to Everything Y...
# 7         8                                               1984
# 8         9                                  Rich Dad Poor Dad
# ...

# %%
mydb = connection.connect(host="localhost", database = 'book_data',user="jihan", passwd="rahasia",use_pure=True)
query = "Select * from book_info where publisher_id = 14;"
publisher_14 = pd.read_sql(mydb, query)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [4], line 3
#       1 mydb = connection.connect(host="localhost", database = 'book_data',user="jihan", passwd="rahasia",use_pure=True)
#       2 query = "Select * from book_info where publisher_id = 14;"
# ----> 3 publisher_14 = pd.read_sql(mydb, query)
#
# File ~/PycharmProjects/Bookstore_Analysis/venv/lib/python3.10/site-packages/pandas/io/sql.py:562, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     437 def read_sql(
#     438     sql,
#     439     con,
#    (...)
#     445     chunksize: int | None = None,
#     446 ) -> DataFrame | Iterator[DataFrame]:
#     447     """
#     448     Read SQL query or database table into a DataFrame.
#     449
#    (...)
#     560     1           1  2010-11-12
#     561     """
# --> 562     pandas_sql = pandasSQL_builder(con)
# ...
